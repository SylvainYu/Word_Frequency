# %%
import pandas as pd

df = pd.read_excel('~\Downloads\AllRecords191109.xlsx')

# %%
data = df.loc[0].values

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
print("读取指定行的数据：\n{0}".format(data))
# Out:
# 读取指定行的数据：
# ['   喷淋等消防水管连接处未作除麻防腐；   接风口的风管镀锌钢板未咬接或铆接，采用拼接，拼缝处漏风严重；  桥架未逐个与吊架做固定； 材料报审资料建设单位仅盖章，未签字，及意见； 紧定式电管无钉或钉头未拧掉现象普遍，成束电管墙内暗敷无间距； 施工组织设计未经公司、建设单位 卫生间洗脸盆排水管存水弯设置于楼板下； 项目经理任命文件未见； 隐蔽验收记录建设单位仅盖章，未签字，及意见；缺日期； '
#  Timestamp('2014-05-13 00:00:00') '吴明华']

# %%
type(data)
# Out:
# numpy.ndarray

# %%
type(df.loc[0])
# Out:
# pandas.core.series.Series

# %%
 type(df.loc[df['检查时间'] > '2018-01-01 00:00:00', ['操作人']])
# Out:
# pandas.core.frame.DataFrame

# %%
df.loc[df['操作人'] == '邬嘉荪', ['检查结果']].to_csv()
# Out:
# ',检查结果\r\n12, 三层B轴—8轴钢柱与4根大梁的连接结点施工与审图图纸和补充白图均不一致（两版图纸也不一致） 二层H轴—5轴南向钢柱与钢大梁的连接结点设计未明确螺栓的规格和数量 钢构件出厂合格证监理未签字盖章。 高强螺栓摩擦面抗滑移工厂制作复试报告未见。 焊接工艺评定（制作、现场）评定人、审批人未签字。 三层E轴—8轴的钢柱与钢梁连接高强螺栓安装不符合要求 施工单位质量回复单注册建造师未盖注册章 \r\n66,&#x0A;电力管线没有办理管管线绿卡 监测方案未经围护设计确认，且评审时所提供的方案非现在的监测单位编制 三轴水泥搅拌桩和双轴水泥土搅拌桩浆液试块强度检验围护设计要求按每台班抽查2根桩，每根桩不少于2个取样点，每个取样点制作3件水泥土试块，现场水泥土试块制作组数与设计要求不符。 深基坑施工方案专家评审意见的回复不够明确与直接，建委科技委的指导意见未见 围护设计评审的回复意见未提供 未提供基坑周边建筑物和构筑物的调查记录 支撑及型钢立柱检验批资料未见。 \r\n165,&#x0A;4月1日浇捣的C35P6、C50P6，抗渗试块报告未见； 地下室独立柱C50同条件试块未留置，剪力外墙C50P6、地下室顶板C30同条件试块各只留置1组，无法进行同条件实体评定； 地下室外墙板混凝土个别裂缝未处理 监理日记和监理旁站记录填写不规范，未能反映施工现场实际施工情况。 楼梯施工缝处存在夹渣情况需处理 施工日记填写不规范，未能反映施工现场实际施工情况； 现场未按不同钢筋生产企业进行机械连接用套筒接头工艺的工艺试验； 直螺纹套筒进场数量、原材料复试报告未见；现场套筒连接接头复试未按楼层进行。 \r\n242,05号二级箱，2个保护开关，下接两路动力回路 17号二级配电箱，2个保护开关下接2路动力回路。 1号楼，15号三级箱，主闸刀开关下接两路。 1号楼，4层三级箱，无编号，电工巡视记录知道2月20日，且进箱子电缆沿脚手架敷设未绝缘。 5层楼梯间（轴线8-15、8-16）搭设不规范，立杆悬空。 6层模板支撑缺扫地杆，局部水平杆未双向连续设置。 7号楼，19号三级箱，电工巡视记录只到2月20日，其中一个插座脱落。 安标内外审企业未组织审核。 企业节后对大型机械检查未形成书面资料 外脚手架北侧四排一隔离未设置。 外脚手架操作层三步踢脚线未设置。 危大工程（大机安装）施工
# ...

# %%
import wordfrequency_jieba as wf
import stopwords_cn as sw

# %%
cleanwords = sw.drop_stopwords(df.loc[df['操作人'] == '邬嘉荪', ['检查结果']].to_csv())
# Out:
# Building prefix dict from the default dictionary ...
# Loading model from cache C:\Users\ADMINI~1\AppData\Local\Temp\jieba.cache
# Loading model cost 0.731 seconds.
# Prefix dict has been built succesfully.

# %%
print(cleanwords)
# Out:
# 检查 /
#  /  /三层 /B /轴 /轴 /钢柱 /根 /大梁 /连接 /结点 /审图 /图纸 /补充 /白图 /两 /版图 /纸 /  /二层 /H /轴 /轴 /南向 /钢柱 /钢 /大梁 /连接 /结点 /设计 /未 /螺栓 /规格 /数量 /  /钢 /构件 /出厂 /合格证 /监理 /未 /签字 /盖章 /  /高强 /螺栓 /摩擦 /面 /抗滑移 /工厂 /制作 /复试 /报告 /  /焊接 /工艺 /评定 /制作 /评定 /审批 /人未 /签字 /  /三层 /E /轴 /轴 /钢柱 /钢梁 /连接 /高强 /螺栓 /安装 /  /施工单位 /质量 /回复 /注册 /建造师 /未盖 /注册 /章 /  /
#  /&# /x0A /电力 /管线 /办理 /管线 /绿卡 /  /监测 /方案 /未经 /围护 /设计 /确认 /评审 /时所 /提供 /方案 /非 /监测 /编制 /  /三轴 /水泥 /搅拌 /桩 /双轴 /水 /泥土 /搅拌 /桩 /浆液 /试块 /强度 /检验 /围护 /设计 /台班 /根桩 /每根桩 /取样 /点 /取样 /点 /制作 /件 /水 /泥土 /试块 /水 /泥土 /试块 /制作组 /设计 /  /深基坑 /方案 /专家 /评审 /意见 /回复 /建委 /科技委 /指导 /意见 /  /围护 /设计 /评审 /回复 /意见 /未 /提供 /  /未 /提供 /基坑 /周边 /建筑物 /构筑物 /调查 /记录 /  /支撑 /型钢 /立柱 /检验 /批 /资料 /  /
# ...

# %%
wf.get_words(sw.drop_stopwords(df.iloc[:, 0].to_csv())) # 这里提取出来的就不光是‘检查结果’内容了，还有其他所有列内容？
# Out:
# C:\Users\Administrator\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: FutureWarning: The signature of `Series.to_csv` was aligned to that of `DataFrame.to_csv`, and argument 'header' will change its default value from False to True: please pass an explicit value to suppress this warning.
#   """Entry point for launching an IPython kernel.
# 常用词频统计结果
# 全文词汇数量： 854284
# 设置 -->  10874
# 设计 -->  9755
# 报告 -->  8652
# 监理 -->  7004
# 防护 -->  6943
# 钢筋 -->  6779
# 记录 -->  6584
# 方案 -->  6317
# 资料 -->  6138
# 质量 -->  5976
# 检测 -->  5810
# 验收 -->  5650
# 人员 -->  5642
# 材料 -->  5420
# 脚手架 -->  5226
# 相关 -->  4036
# 施工现场 -->  3916
# 安装 -->  3886
# 负责人 -->  3824
# 屋面 -->  3653
# 监督 -->  3389
# 复试 -->  3353
# 规范 -->  3348
# 内容 -->  3292
# 连接 -->  3169
# 组织 -->  3096
# 基坑 -->  3082
# 台账 -->  2980
# 施工单位 -->  2933
# 工程 -->  2855
# 建设 -->  2854
# 混凝土 -->  2841
# 签字 -->  2761
# 提供 -->  2735
# 图纸 -->  2722
# 作业 -->  2685
# 文件 -->  2501
# 检查 -->  2500
# 栏杆 -->  2488
# 技术 -->  2445
# 结构 -->  2412
# ...

# %%
wf.get_words(cleanwords)
# Out:
# 常用词频统计结果
# 全文词汇数量： 18507
# 设计 -->  379
# 报告 -->  320
# 复试 -->  224
# 屋面 -->  207
# 防护 -->  148
# 幕墙 -->  138
# 连接 -->  136
# 钢筋 -->  133
# 图纸 -->  132
# 保温 -->  131
# 方案 -->  129
# 安装 -->  126
# 脚手架 -->  107
# 记录 -->  98
# 地下室 -->  97
# 监理 -->  90
# 资料 -->  86
# 检测 -->  86
# 节能 -->  84
# 支撑 -->  82
# 验收 -->  76
# 敷设 -->  74
# 设置 -->  74
# 方式 -->  73
# 侧向 -->  73
# 规范 -->  72
# 设计变更 -->  72
# 提供 -->  68
# 混凝土 -->  66
# 审图 -->  65
# 钢结构 -->  65
# 消防 -->  65
# 检验 -->  64
# 导管 -->  64
# 防水 -->  63
# 支架 -->  63
# 防火 -->  60
# 相关 -->  58
# 强度 -->  57
# 外墙 -->  57
# 材料 -->  56
# 玻璃 -->  54
# 人员 -->  54
# 上海 -->  53
# 风管 -->  53
# 大于 -->  52
# 合同 -->  52
# 尚未 -->  52
# 墙体 -->  52
# 项目经理 -->  52
# 试块 -->  51
# 基础 -->  51
# 工艺 -->  50
# 合格证 -->  49
# 构造 -->  49
# 吊顶 -->  49
# 接头 -->  48
# 石材 -->  48
# 墙面 -->  48
# 模板 -->  47
# 审批 -->  46
# 机械 -->  46
# 砂浆 -->  46
# 通道 -->  46
# 室内 -->  46
# 楼梯 -->  45
# 管道 -->  45
# 严密 -->  44
# 基坑 -->  43
# 临时 -->  43
# 结构 -->  43
# 生产 -->  42
# 围护 -->  41
# ...
