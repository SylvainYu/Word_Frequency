# %%
import pandas as pd

df = pd.read_excel('Complaint.xls')

# %%
data = df.loc[0].values

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
print("读取指定行的数据：\n{0}".format(data))
# Out:
# 读取指定行的数据：
# [12 2007 Timestamp('2007-12-04 00:00:00') 'SHSJGB2007120400013'
#  'SHSJGB2007120400013' '上海市建筑建材业信访室' '来电' '住宅质量' '裂缝' nan '裂缝'
#  '反映闵行区浦江镇江沿燕路229弄（世博家园）87号502室处家中有裂缝（整墙），请处理。' '一般件' '12319城建服务热线'
#  701441283 '王女士' 13817125117 '否' 1 1 0.0 '闵行' '江万里' '上海市建设工程安全质量监督总站' '是'
#  '否' '否' '否' '2007-12-5 江万里: 拟请查处一科阅处，妥否，请张常庆副站长阅示。2007年12月5日' '已归档'
#  Timestamp('2008-01-03 00:00:00') Timestamp('2008-02-03 00:00:00')
#  Timestamp('2008-02-03 00:00:00') '是' '是']

# %%
type(data)
# Out:
# numpy.ndarray

# %%
type(df.loc[0])
# Out:
# pandas.core.series.Series

# %%
df.loc[df['信访大类 '] == '住宅质量', ['投诉主要内容 ']].to_csv()
# Out:
# ',投诉主要内容 \r\n0,反映闵行区浦江镇江沿燕路229弄（世博家园）87号502室处家中有裂缝（整墙），请处理。\r\n1,2007-12-06 浦江镇 南江燕路69弄16号301室 （七街坊）: 催办编号：0701298374，业主去年10月交房，现家中客厅墙壁已有开裂现象，请核实处理。联系电话：34505672（重复投诉次数3次）\r\n2,2007-12-07 蒙山路581弄39号302室: 反映该处房屋（去年入住）整幢墙面都有开裂情况，存在安全隐患，请尽快核实处理。（要求信息保密）\r\n3,2007-12-09 罗泾镇 陈川路555弄112号501室: 反映该户于07年6月交房，现家中墙面有裂缝产生，请尽快核实处理并回复。（联系电话：13162203850）\r\n4,2007-12-10 汶水东路298弄17号1702室: 重复投诉3次，反映该处05年11月交房后，1、现有45度裂缝，2、该处停车库地下楼梯处墙面有漏水现象，向上海裕景房产有限公司开发商报修未果，请处理。（联系电话：13901953487）\r\n5,2007-12-10 沪南公路2518弄8号301室: 反映该户于05年11月交房，现家中地面有裂缝产生，请尽快联系核实处理。（属于百舸房产）重复3次\r\n6,2007-12-17 万荣路1050弄17号502室: 反映该房2003年12月31日交付使用，05年发生质量问题（全部墙面开裂严重，窗框变型等情况），多次联系开发商处理未果，反映后有相关部门查看，表示其只能督促开发商维修，其它无法处理，对此投诉人非常不满，且现反映人称天花板也开裂，要求相关部门尽快联系开发商能够协调处理并给予其一个实事求是的书面回复。（重复5次）\r\n7,2007-12-20 万容路1050弄21号702室: 反映于2003年12月31日交付使用的商品房，入住3年来墙面有明显的开裂现象，（承重墙、客厅的隔墙）且房屋多处有渗漏现象，门和窗已无法正常关起， 向民强开发商反映多次未得到解决，请核实处理并回复。（联系电话：66311815）（重复投诉5次）\r\n8,2007-12-20 张杨北路555弄22号702室: 反映其处新购商品房房顶有开裂现象，建管办有关部门已与他联系过，反映人表示至今没有给其回复且没有相关部门来维修，请核实处理。（联系电话：1380
# ...

# %%
import wordfrequency_jieba as wf
import stopwords_cn as sw

# %%
cleanwords = sw.drop_stopwords(df.loc[df['信访大类 '] == '住宅质量', ['投诉主要内容 ']].to_csv())
# Out:
# Building prefix dict from the default dictionary ...
# Dumping model to file cache C:\Users\ADMINI~1\AppData\Local\Temp\jieba.cache
# Loading model cost 0.836 seconds.
# Prefix dict has been built succesfully.

# %%
print(cleanwords)
# Out:
# 投诉 /内容 /  /
#  /闵行区 /浦江镇 /江沿 /燕路 /229 /弄 /世博 /家园 /号 /502 /室处 /家中 /裂缝 /整墙 /请 /
#  /2007 /  /浦江镇 /  /南江 /燕路 /弄 /号 /301 /室 /  /街坊 /  /催办 /编号 /0701298374 /业主 /去年 /交房 /现 /家中 /客厅 /墙壁 /已有 /开裂 /请 /核实 /联系电话 /34505672 /重复 /投诉 /次数 /次 /
#  /2007 /  /蒙 /山路 /581 /弄 /号 /302 /室 /  /该处 /房屋 /去年 /入住 /整幢 /墙面 /开裂 /安全隐患 /请 /核实 /信息 /保密 /
#  /2007 /  /罗泾镇 /  /陈川路 /555 /弄 /112 /号 /501 /室 /  /该户 /交房 /现 /家中 /墙面 /裂缝 /请 /核实 /回复 /联系电话 /13162203850 /
#  /2007 /  /汶水 /东路 /298 /弄 /号 /1702 /室 /  /重复 /投诉 /次 /该处 /交房 /现有 /度 /裂缝 /该处 /停车库 /地下 /楼梯 /处 /墙面 /漏水 /上海 /裕景 /房产 /有限公司 /开发商 /报修 /未果 /请 /联系电话 /139019 /487 /
#  /2007 /  /沪 /南 /公路 /2518 /弄 /号 /301 /室 /  /该户 /交房 /现 /家中 /地面 /裂缝 /请 /核实 /百舸 /房产 /重复 /次 /
#  /2007 /  /万荣 /路 /1050 /弄 /号 /502 /室 /  /该房 /2003 /交付使用 /发生 /质量 /墙面 /开裂 /窗框 /变型 /开发商 /未果 /相关 /部门 /查看 /只能 /督促 /开发商 /维修 /对此 /投诉 /且现 /人称 /天花板 /开裂 /相关 /部门 /开发商 /协调 /给予 /实事求是 /书面 /回复 /重复 /次 /
# ...

# %%
wf.get_words(sw.drop_stopwords(df.iloc[:, 0].to_csv()))
# Out:
# C:\Users\Administrator\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: FutureWarning: The signature of `Series.to_csv` was aligned to that of `DataFrame.to_csv`, and argument 'header' will change its default value from False to True: please pass an explicit value to suppress this warning.
#   """Entry point for launching an IPython kernel.
# 常用词频统计结果
# 全文词汇数量： 1785
# 00 -->  2
# 101 -->  1
# 102 -->  1
# 103 -->  1
# 104 -->  1
# 105 -->  1
# 106 -->  1
# 107 -->  1
# 108 -->  1
# 109 -->  1
# 110 -->  1
# 111 -->  1
# 112 -->  1
# 113 -->  1
# 115 -->  1
# 116 -->  1
# 117 -->  1
# 118 -->  1
# 119 -->  1
# 120 -->  1
# 122 -->  1
# 123 -->  1
# 124 -->  1
# 125 -->  1
# 126 -->  1
# 127 -->  1
# 128 -->  1
# 129 -->  1
# 130 -->  1
# 131 -->  1
# 132 -->  1
# 133 -->  1
# 134 -->  1
# 135 -->  1
# 136 -->  1
# 137 -->  1
# 138 -->  1
# 139 -->  1
# 150 -->  1
# 151 -->  1
# 152 -->  1
# 154 -->  1
# 155 -->  1
# 156 -->  1
# 157 -->  1
# 158 -->  1
# 159 -->  1
# 160 -->  1
# ...

# %%
wf.get_words(cleanwords)
# Out:
# 常用词频统计结果
# 全文词汇数量： 45487
# 房屋 -->  1216
# 开发商 -->  1103
# 回复 -->  1014
# 联系电话 -->  967
# 2008 -->  907
# 该处 -->  899
# 核实 -->  789
# 墙面 -->  604
# 交房 -->  587
# 部门 -->  556
# 重复 -->  477
# 发现 -->  460
# 未果 -->  454
# 渗水 -->  448
# 2009 -->  445
# 漏水 -->  435
# 开裂 -->  420
# 质量 -->  395
# 维修 -->  383
# 裂缝 -->  380
# 求决 -->  376
# 居民 -->  376
# 相关 -->  318
# 影响 -->  298
# 生活 -->  282
# 外墙 -->  264
# 渗漏 -->  263
# 物业 -->  253
# 该户 -->  232
# 保修期 -->  228
# 家中 -->  223
# 商品房 -->  221
# 屋顶 -->  196
# 投诉 -->  186
# 入住 -->  181
# 装修 -->  170
# 阳台 -->  164
# 101 -->  160
# 解决 -->  158
# 对此 -->  152
# 交付使用 -->  148
# 上门 -->  147
# 602 -->  144
# 室处 -->  142
# 卫生间 -->  139
# 请速 -->  136
# 小区 -->  135
# 人称 -->  134
# 导致 -->  132
# 图纸 -->  126
# 有限公司 -->  123
# 北路 -->  123
# 402 -->  123
# 房间 -->  123
# 上海 -->  119
# 闵行区 -->  117
# 购买 -->  116
# 浦东 -->  112
# 公分 -->  111
# 2007 -->  108
# 201 -->  108
# 修复 -->  105
# 501 -->  103
# 卧室 -->  103
# 多处 -->  101
# 安全隐患 -->  99
# 南路 -->  99
# ...
