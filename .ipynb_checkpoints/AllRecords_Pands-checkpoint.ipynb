# %%
import pandas as pd

df = pd.read_csv('~\Downloads\AllRecords200518_Districts.csv') # DataFrame结构，提取年份、月份、日期和属地、姓名，分别统计
#df = pd.read_csv(r'C:\users\administrator\documents\github\word_frequency\AllRecords200518_Districts.csv') # DataFrame结构，提取年份、月份、日期和属地、姓名，分别统计

# %%
data = df.loc[0].values

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
print("读取指定行的数据：\n{0}".format(data))
# Out:
# 读取指定行的数据：
# ['    质量：1原材料综合台账、监理监督台账未建立        4、监理平行检测未开展     2、监理单位工程例会记录无  5、仪器标定证书未见 3、监理带班记录未见   市场1、总包单位岗位人员配备缺标准员、劳务员      '
#  '2018/9/6' '黄家华' '崇明']

# %%
type(data)
# Out:
# numpy.ndarray

# %%
type(df.loc[0])
# Out:
# pandas.core.series.Series

# %%
 type(df.loc[df['日期'] > '2018-01-01 00:00:00', ['姓名']])
# Out:
# pandas.core.frame.DataFrame

# %%
df.loc[df['姓名'] == '邬嘉荪', ['监督记录']].to_csv()
# Out:
# ',监督记录\r\n65, 三层B轴—8轴钢柱与4根大梁的连接结点施工与审图图纸和补充白图均不一致（两版图纸也不一致） 二层H轴—5轴南向钢柱与钢大梁的连接结点设计未明确螺栓的规格和数量 钢构件出厂合格证监理未签字盖章。 高强螺栓摩擦面抗滑移工厂制作复试报告未见。 焊接工艺评定（制作、现场）评定人、审批人未签字。 三层E轴—8轴的钢柱与钢梁连接高强螺栓安装不符合要求 施工单位质量回复单注册建造师未盖注册章 \r\n159,&#x0A;《建筑工地复工检查表》与统一表式不相符。 工地进口的健康观测点不完善。 未对代建的相关人员进行防疫交底。 无社区联络人。 \r\n201,&#x0A;32.5水泥的合格证和水泥安定性的复试报告。 设计未明确屋面防水卷材聚乙烯丙纶防水材料的厚度。 屋面红色蝴蝶瓦的合格证、油漆的型式检验报告未见。 线缆未复试。 照明开关线用1.5平方导线。配线用钢导管和图纸要求不符 智能系统、消防系统未见资料 \r\n207,&#x0A;4层局部大型玻璃饰面未能提供安装详图和隐蔽验收记录 地下二层有一扇门正在加工商未安装 多功能厅玻璃隔断10mm钢化玻璃+透明防爆膜，目前透明防爆膜为贴，相关合格证和型式检验报告未见；办公室玻璃隔断5mm钢化玻璃的3c认证证书未见。 防火门资料不齐全，设计要求和现场不一致。 风管保湿局部处理工序不到位。支架保温层内。 建筑设计说明（三）和（八）针对幕墙抗风压性的要求不一致，（三）抗风压性3级，（八）抗风压性2级，现场复试，2级。 洁净室空调系统施工工序不对，满足不了洁净空调施工要求。 局部风口安装不平 局部开关顺序应调整 局部内墙开裂正在修补 木饰面甲醛含量复试报告未见；木饰面燃烧性能型式检验报告未见。 幕墙结构胶和密封胶复试报告未见。 配电箱柜局部电缆连接用降接转容方式连接 强弱电回路敷设方式不对，应调整。 透光膜天花（A级）燃烧性型式检验报告未见。 西北面入口处墙面平顶保温用水泥基无机保温砂浆，现场无法查明，资料中未提供节能施工的隐蔽验收记录佐证 硬包中的成品硬包饰面板合格证、B1级燃烧性型式检验报告未见。 \r\n209,&#x0A;4月1日浇捣的C35P6、C50P6，抗渗试块报告未见； 地下室独立柱C50同条件试块未留置，剪力外墙C50P6、地下室顶板C30同条件试块各只留置1组，无法进行同条件实体评定； 地下
# ...

# %%
f = open('E:/test.txt','w')
 
f.write(df.loc[df['姓名'] == '邬嘉荪', ['监督记录']].to_csv())
 
f.close()

# %%
import wordfrequency_jieba as wf
import stopwords_cn as sw

# %%
# cleanwords: 特定人监督记录去停止词后的结果；
# cleanwords中使用'/'分隔词汇，这由drop_stopwords()定义
cleanwords = sw.drop_stopwords(df.loc[df['姓名'] == '邬嘉荪', ['监督记录']].to_csv())
# Out:
# Building prefix dict from the default dictionary ...
# Loading model from cache C:\Users\ADMINI~1\AppData\Local\Temp\jieba.cache
# Loading model cost 0.762 seconds.
# Prefix dict has been built succesfully.

# %%
print(cleanwords)
# Out:
# 监督 /记录 /
#  /  /三层 /B /轴 /轴 /钢柱 /根 /大梁 /连接 /结点 /审图 /图纸 /补充 /白图 /两 /版图 /纸 /  /二层 /H /轴 /轴 /南向 /钢柱 /钢 /大梁 /连接 /结点 /设计 /未 /螺栓 /规格 /数量 /  /钢构件 /出厂 /合格证 /监理 /未 /签字 /盖章 /  /高强螺栓 /摩擦面 /抗滑移 /工厂 /制作 /复试 /报告 /  /焊接 /工艺 /评定 /制作 /评定 /审批人 /未 /签字 /  /三层 /E /轴 /轴 /钢柱 /钢梁 /连接 /高强螺栓 /安装 /  /施工单位 /质量 /回复 /注册 /建造师 /未盖 /注册章 /  /
#  /159 /&# /x0A /建筑工地 /复工 /检查表 /统一 /表式 /相符 /  /工地 /进口 /健康 /观测点 /完善 /  /未 /对代建 /相关 /人员 /防疫 /交底 /  /社区 /联络人 /  /
#  /201 /&# /x0A /32.5 /水泥 /合格证 /水泥 /安定性 /复试 /报告 /  /设计 /未 /屋面 /防水 /卷材 /聚乙烯 /丙纶 /防水材料 /厚度 /  /屋面 /红色 /蝴蝶瓦 /合格证 /油漆 /型式检验 /报告 /  /线缆 /未 /复试 /  /照明 /开关 /线用 /1.5 /平方 /导线 /配线 /钢导管 /图纸 /  /智能 /消防系统 /资料 /  /
# ...

# %%
wf.get_words(cleanwords)
# Out:
# 常用词频统计结果
# 全文词汇数量： 20403
# 设计 -->  421
# 报告 -->  344
# 复试 -->  241
# 屋面 -->  231
# 连接 -->  154
# 钢筋 -->  152
# 图纸 -->  148
# 方案 -->  140
# 防护 -->  134
# 安装 -->  132
# 保温 -->  119
# 记录 -->  117
# 监理 -->  114
# 资料 -->  114
# 检测 -->  111
# 幕墙 -->  109
# 地下室 -->  101
# 设计变更 -->  87
# 节能 -->  85
# 方式 -->  82
# 敷设 -->  81
# 设置 -->  79
# 混凝土 -->  78
# 验收 -->  76
# 钢结构 -->  75
# 未做 -->  74
# 规范 -->  73
# 侧向 -->  73
# 防水 -->  72
# 支撑 -->  72
# 防火 -->  71
# 材料 -->  68
# 消防 -->  67
# 相关 -->  64
# 支架 -->  64
# 合同 -->  64
# 人员 -->  63
# 外墙 -->  61
# 导管 -->  60
# 合格证 -->  59
# 尚未 -->  59
# 玻璃 -->  58
# 基础 -->  58
# 墙面 -->  57
# 试块 -->  57
# 强度 -->  57
# 上海 -->  57
# 吊顶 -->  56
# 接头 -->  55
# 大于 -->  55
# 脚手架 -->  55
# 墙体 -->  55
# 风管 -->  54
# 临时 -->  54
# 外脚手架 -->  53
# 项目经理 -->  53
# 审图 -->  52
# 机械 -->  51
# 审批 -->  51
# 构造 -->  51
# 室内 -->  51
# 防火门 -->  50
# 未提供 -->  49
# 接地 -->  49
# 结构 -->  49
# 企业 -->  48
# 改为 -->  48
# 卷材 -->  47
# 模板 -->  47
# 无障碍 -->  47
# 生产 -->  46
# 设备 -->  46
# ...

# %%
u = open('E:/test.txt', 'w', encoding='utf-8')

u.write(cleanwords)

u.close()

# %%
from gensim.models import word2vec

# 加载语料
# 2020-7-7资料显示word2vec.Text8Corpus类从一个叫做'text8'的语料库获取数据，该预料来源于
# http://mattmahoney.net/dc/text8.zip
# 该类有调试参数，限定获取不同的预料长度等等
#sentences = word2vec.Text8Corpus('E:/test.txt') 

model = word2vec.Word2Vec(cleanwords, min_count=1) # 训练模型
model.save('someone.model') # 保存模型
model = word2vec.Word2Vec.load('someone.model') # 加载模型

# 打印指定词语的关联词
#for e in model.wv.most_similar(positive=['审图'], topn=10):
#    print(e[0], e[1])

#print(len(model.wv.vocab))  # cleanwords作为语料，Word2Vec训练后vocab数量1390个
print(model.wv.vocab) # cleanwords作为语料，Word2Vec训练后都是单个汉字的vocab，1390个
# Out:
# {'监': <gensim.models.keyedvectors.Vocab object at 0x0000019F48D587C8>, '督': <gensim.models.keyedvectors.Vocab object at 0x0000019F48D586C8>, ' ': <gensim.models.keyedvectors.Vocab object at 0x0000019F48D58688>, '/': <gensim.models.keyedvectors.Vocab object at 0x0000019F48D58648>, '记': <gensim.models.keyedvectors.Vocab object at 0x0000019F48D58608>, '录': <gensim.models.keyedvectors.Vocab object at 0x0000019F48D585C8>, '\r': <gensim.models.keyedvectors.Vocab object at 0x0000019F48D58588>, '\n': <gensim.models.keyedvectors.Vocab object at 0x0000019F48D58548>, '三': <gensim.models.keyedvectors.Vocab object at 0x0000019F48D58508>, '层': <gensim.models.keyedvectors.Vocab object at 0x0000019F48D584C8>, 'B': <gensim.models.keyedvectors.Vocab object at 0x0000019F48D58488>, '轴': <gensim.models.keyedvectors.Vocab object at 0x0000019F48D58448>, '钢': <gensim.models.keyedvectors.Vocab object at 0x0000019F48D58408>, '柱': <gensim.models.keyedvectors.Vocab object at 0x0000019F48D583C8>, '根': <gensim.mo
# ...

# %%
wf.get_words(sw.drop_stopwords(df.iloc[:, 0].to_csv())) # 这里提取出来的就不光是‘检查结果’内容了，还有其他所有列内容？
# Out:
# 常用词频统计结果
# 全文词汇数量： 1023901
# 设置 -->  13102
# 设计 -->  11637
# 报告 -->  10111
# 监理 -->  8440
# 记录 -->  8181
# 钢筋 -->  8100
# 方案 -->  8038
# 资料 -->  7306
# 质量 -->  6953
# 人员 -->  6928
# 检测 -->  6843
# 验收 -->  6455
# 防护 -->  6454
# 材料 -->  6411
# 脚手架 -->  5127
# 安装 -->  4731
# 相关 -->  4700
# 施工现场 -->  4579
# 负责人 -->  4519
# 屋面 -->  4210
# 监督 -->  3936
# 基坑 -->  3912
# 复试 -->  3900
# 规范 -->  3871
# 内容 -->  3738
# 组织 -->  3606
# 工程 -->  3575
# 台账 -->  3560
# 建设 -->  3526
# 连接 -->  3525
# 施工单位 -->  3475
# 作业 -->  3459
# 混凝土 -->  3394
# 图纸 -->  3353
# 签字 -->  3238
# 交底 -->  2978
# 技术 -->  2951
# 结构 -->  2912
# 检查 -->  2829
# 编制 -->  2762
# 文件 -->  2758
# 临时 -->  2756
# 齐全 -->  2705
# 审批 -->  2669
# 间距 -->  2664
# 项目经理 -->  2645
# 部位 -->  2645
# 临边 -->  2640
# 消防 -->  2615
# 发现 -->  2608
# 堆放 -->  2528
# 平台 -->  2502
# 支撑 -->  2495
# 用电 -->  2488
# 搭设 -->  2440
# 保温 -->  2416
# 风管 -->  2414
# 报审 -->  2327
# 吊顶 -->  2325
# 各方 -->  2301
# 电线 -->  2258
# 分包 -->  2202
# 手续 -->  2201
# ...

# %%
wf.get_words(cleanwords)
# Out:
# 常用词频统计结果
# 全文词汇数量： 20403
# 设计 -->  421
# 报告 -->  344
# 复试 -->  241
# 屋面 -->  231
# 连接 -->  154
# 钢筋 -->  152
# 图纸 -->  148
# 方案 -->  140
# 防护 -->  134
# 安装 -->  132
# 保温 -->  119
# 记录 -->  117
# 监理 -->  114
# 资料 -->  114
# 检测 -->  111
# 幕墙 -->  109
# 地下室 -->  101
# 设计变更 -->  87
# 节能 -->  85
# 方式 -->  82
# 敷设 -->  81
# 设置 -->  79
# 混凝土 -->  78
# 验收 -->  76
# 钢结构 -->  75
# 未做 -->  74
# 规范 -->  73
# 侧向 -->  73
# 防水 -->  72
# 支撑 -->  72
# 防火 -->  71
# 材料 -->  68
# 消防 -->  67
# 相关 -->  64
# 支架 -->  64
# 合同 -->  64
# 人员 -->  63
# 外墙 -->  61
# 导管 -->  60
# 合格证 -->  59
# 尚未 -->  59
# 玻璃 -->  58
# 基础 -->  58
# 墙面 -->  57
# 试块 -->  57
# 强度 -->  57
# 上海 -->  57
# 吊顶 -->  56
# 接头 -->  55
# 大于 -->  55
# 脚手架 -->  55
# 墙体 -->  55
# 风管 -->  54
# 临时 -->  54
# 外脚手架 -->  53
# 项目经理 -->  53
# 审图 -->  52
# 机械 -->  51
# 审批 -->  51
# 构造 -->  51
# 室内 -->  51
# 防火门 -->  50
# 未提供 -->  49
# 接地 -->  49
# 结构 -->  49
# 企业 -->  48
# 改为 -->  48
# 卷材 -->  47
# 模板 -->  47
# 无障碍 -->  47
# 生产 -->  46
# 设备 -->  46
# ...

# %%
df['姓名'].value_counts()
# Out:
# 李长兴    2458
# 朱喆麟    1592
# 朱振毅    1104
# 崔名山    1008
# 董兴华     963
#        ...
# 林兴        1
# 祝春云       1
# 朱骏        1
# 陈善明       1
# 张征        1
# Name: 姓名, Length: 279, dtype: int64
